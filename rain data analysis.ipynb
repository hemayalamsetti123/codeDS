# %%
import pandas as pd

# %%
data=pd.read_csv("/home/placement/Desktop/hema/rainfall in india 1901-2015.csv")

# %%
data.describe()
# Out:
#               YEAR          JAN          FEB          MAR          APR  \
# count  4116.000000  4112.000000  4113.000000  4110.000000  4112.000000
# mean   1958.218659    18.957320    21.805325    27.359197    43.127432
# std      33.140898    33.585371    35.909488    46.959424    67.831168
# min    1901.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1930.000000     0.600000     0.600000     1.000000     3.000000
# 50%    1958.000000     6.000000     6.700000     7.800000    15.700000
# 75%    1987.000000    22.200000    26.800000    31.300000    49.950000
# max    2015.000000   583.700000   403.500000   605.600000   595.100000
#
#                MAY          JUN          JUL          AUG          SEP  \
# count  4113.000000  4111.000000  4109.000000  4112.000000  4110.000000
# mean     85.745417   230.234444   347.214334   290.263497   197.361922
# std     123.234904   234.710758   269.539667   188.770477   135.408345
# ...

# %%
data.info()#information about data given
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4116 entries, 0 to 4115
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SUBDIVISION  4116 non-null   object
#  1   YEAR         4116 non-null   int64
#  2   JAN          4112 non-null   float64
#  3   FEB          4113 non-null   float64
#  4   MAR          4110 non-null   float64
#  5   APR          4112 non-null   float64
#  6   MAY          4113 non-null   float64
#  7   JUN          4111 non-null   float64
#  8   JUL          4109 non-null   float64
#  9   AUG          4112 non-null   float64
#  10  SEP          4110 non-null   float64
#  11  OCT          4109 non-null   float64
#  12  NOV          4105 non-null   float64
#  13  DEC          4106 non-null   float64
#  14  ANNUAL       4090 non-null   float64
#  15  Jan-Feb      4110 non-null   float64
#  16  Mar-May      4107 non-null   float64
#  17  Jun-Sep      4106 non-null   float64
# ...

# %%
list(data)
# Out:
# ['SUBDIVISION',
#  'YEAR',
#  'JAN',
#  'FEB',
#  'MAR',
#  'APR',
#  'MAY',
#  'JUN',
#  'JUL',
#  'AUG',
#  'SEP',
#  'OCT',
#  'NOV',
#  'DEC',
#  'ANNUAL',
#  'Jan-Feb',
#  'Mar-May',
#  'Jun-Sep',
#  'Oct-Dec']

# %%
data.groupby(['SUBDIVISION']).count()
# Out:
#                                     YEAR  JAN  FEB  MAR  APR  MAY  JUN  JUL  \
# SUBDIVISION
# ANDAMAN & NICOBAR ISLANDS            110  110  110  108  108  109  108  108
# ARUNACHAL PRADESH                     97   96   96   95   97   97   96   96
# ASSAM & MEGHALAYA                    115  115  115  115  115  115  115  115
# BIHAR                                115  115  115  115  115  115  115  115
# CHHATTISGARH                         115  115  115  115  115  115  115  115
# COASTAL ANDHRA PRADESH               115  115  115  115  115  115  115  115
# COASTAL KARNATAKA                    115  114  115  115  115  115  115  115
# EAST MADHYA PRADESH                  115  115  115  115  115  115  115  115
# EAST RAJASTHAN                       115  115  115  115  115  115  115  115
# EAST UTTAR PRADESH                   115  115  115  115  115  115  115  115
# GANGETIC WEST BENGAL                 115  115  115  115  115  115  115  115
# ...

# %%
data.isna().sum()
# Out:
# SUBDIVISION     0
# YEAR            0
# JAN             4
# FEB             3
# MAR             6
# APR             4
# MAY             3
# JUN             5
# JUL             7
# AUG             4
# SEP             6
# OCT             7
# NOV            11
# DEC            10
# ANNUAL         26
# Jan-Feb         6
# Mar-May         9
# Jun-Sep        10
# Oct-Dec        13
# dtype: int64

# %%
data1=data.loc[(data.YEAR<=2010)]

# %%
data1
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1   29.2    2.3  528.8
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8   12.2    0.0  446.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0    0.0    1.0  235.1
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7    0.0  202.4  304.5
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0    3.3   26.9  279.5
# ...                         ...   ...   ...    ...    ...    ...    ...
# 4106                LAKSHADWEEP  2006  20.1    0.0   33.0    0.3  327.9
# 4107                LAKSHADWEEP  2007   2.5    4.2    0.2   22.2  166.2
# 4108                LAKSHADWEEP  2008   5.5   19.8  120.7   15.8  180.4
# 4109                LAKSHADWEEP  2009   4.7    1.5    0.1   18.1  162.1
# 4110                LAKSHADWEEP  2010  18.8    0.0    1.2   35.6   79.0
#
#         JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# ...

# %%
data1=data.loc[(data.YEAR<2010)]#data till year 2010

# %%
data1
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1   29.2    2.3  528.8
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8   12.2    0.0  446.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0    0.0    1.0  235.1
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7    0.0  202.4  304.5
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0    3.3   26.9  279.5
# ...                         ...   ...   ...    ...    ...    ...    ...
# 4105                LAKSHADWEEP  2005  17.6   11.1    0.0   37.0   92.8
# 4106                LAKSHADWEEP  2006  20.1    0.0   33.0    0.3  327.9
# 4107                LAKSHADWEEP  2007   2.5    4.2    0.2   22.2  166.2
# 4108                LAKSHADWEEP  2008   5.5   19.8  120.7   15.8  180.4
# 4109                LAKSHADWEEP  2009   4.7    1.5    0.1   18.1  162.1
#
#         JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# ...

# %%
data2=data.drop(['ANNUAL','Jan-Feb','Mar-May','Jun-Sep','Oct-Dec'],axis=1)

# %%
data2
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
data2['SUBDIVISION'].unique()
# Out:
# array(['ANDAMAN & NICOBAR ISLANDS', 'ARUNACHAL PRADESH',
#        'ASSAM & MEGHALAYA', 'NAGA MANI MIZO TRIPURA',
#        'SUB HIMALAYAN WEST BENGAL & SIKKIM', 'GANGETIC WEST BENGAL',
#        'ORISSA', 'JHARKHAND', 'BIHAR', 'EAST UTTAR PRADESH',
#        'WEST UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA DELHI & CHANDIGARH',
#        'PUNJAB', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'WEST RAJASTHAN',
#        'EAST RAJASTHAN', 'WEST MADHYA PRADESH', 'EAST MADHYA PRADESH',
#        'GUJARAT REGION', 'SAURASHTRA & KUTCH', 'KONKAN & GOA',
#        'MADHYA MAHARASHTRA', 'MATATHWADA', 'VIDARBHA', 'CHHATTISGARH',
#        'COASTAL ANDHRA PRADESH', 'TELANGANA', 'RAYALSEEMA', 'TAMIL NADU',
#        'COASTAL KARNATAKA', 'NORTH INTERIOR KARNATAKA',
#        'SOUTH INTERIOR KARNATAKA', 'KERALA', 'LAKSHADWEEP'], dtype=object)

# %%
data3=data2.loc[(data2.SUBDIVISION=="COASTAL ANDHRA PRADESH")]

# %%
data3
# Out:
#                  SUBDIVISION  YEAR   JAN   FEB   MAR   APR    MAY    JUN  \
# 3082  COASTAL ANDHRA PRADESH  1901  18.8  80.9   7.2  28.7   68.7   77.7
# 3083  COASTAL ANDHRA PRADESH  1902   2.0   0.0   2.8  23.9   37.6   72.6
# 3084  COASTAL ANDHRA PRADESH  1903   0.8  13.3   0.2   6.2   73.4  154.0
# 3085  COASTAL ANDHRA PRADESH  1904   1.3   0.0   5.4   3.0  136.3  107.8
# 3086  COASTAL ANDHRA PRADESH  1905   1.1  16.7  68.0  37.0   68.8   84.4
# ...                      ...   ...   ...   ...   ...   ...    ...    ...
# 3192  COASTAL ANDHRA PRADESH  2011   0.0  17.9   0.9  62.3   67.9   86.8
# 3193  COASTAL ANDHRA PRADESH  2012  37.6   0.0   2.7  24.0   39.3   95.4
# 3194  COASTAL ANDHRA PRADESH  2013   2.0  29.6   0.2  48.0   28.2  127.5
# 3195  COASTAL ANDHRA PRADESH  2014   0.4   1.2   9.1   6.0  112.9   45.7
# 3196  COASTAL ANDHRA PRADESH  2015   2.0   0.6   5.5  32.3   34.1  283.8
#
#         JUL    AUG    SEP    OCT    NOV   DEC
# ...

# %%
data3.isna().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# dtype: int64

# %%
data3['ANNUAL RAIN']=data3.apply(lambda row:row.JAN + row.FEB + row.MAR + row.APR + row.MAY + row.JUN + row.JUL + row.AUG + row.SEP + row.OCT + row.NOV + row.DEC,axis=1)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data3
# Out:
#                  SUBDIVISION  YEAR   JAN   FEB   MAR   APR    MAY    JUN  \
# 3082  COASTAL ANDHRA PRADESH  1901  18.8  80.9   7.2  28.7   68.7   77.7
# 3083  COASTAL ANDHRA PRADESH  1902   2.0   0.0   2.8  23.9   37.6   72.6
# 3084  COASTAL ANDHRA PRADESH  1903   0.8  13.3   0.2   6.2   73.4  154.0
# 3085  COASTAL ANDHRA PRADESH  1904   1.3   0.0   5.4   3.0  136.3  107.8
# 3086  COASTAL ANDHRA PRADESH  1905   1.1  16.7  68.0  37.0   68.8   84.4
# ...                      ...   ...   ...   ...   ...   ...    ...    ...
# 3192  COASTAL ANDHRA PRADESH  2011   0.0  17.9   0.9  62.3   67.9   86.8
# 3193  COASTAL ANDHRA PRADESH  2012  37.6   0.0   2.7  24.0   39.3   95.4
# 3194  COASTAL ANDHRA PRADESH  2013   2.0  29.6   0.2  48.0   28.2  127.5
# 3195  COASTAL ANDHRA PRADESH  2014   0.4   1.2   9.1   6.0  112.9   45.7
# 3196  COASTAL ANDHRA PRADESH  2015   2.0   0.6   5.5  32.3   34.1  283.8
#
#         JUL    AUG    SEP    OCT    NOV   DEC  ANNUAL RAIN
# ...

# %%
data4=data3.drop(['SUBDIVISION'],axis=1)

# %%
data4
# Out:
#       YEAR   JAN   FEB   MAR   APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 3082  1901  18.8  80.9   7.2  28.7   68.7   77.7  113.0  133.7  125.3  173.4
# 3083  1902   2.0   0.0   2.8  23.9   37.6   72.6  144.5  236.1  204.5  262.0
# 3084  1903   0.8  13.3   0.2   6.2   73.4  154.0  248.6  258.0  216.5  159.1
# 3085  1904   1.3   0.0   5.4   3.0  136.3  107.8  120.2  117.7  116.8  240.9
# 3086  1905   1.1  16.7  68.0  37.0   68.8   84.4   64.6  210.8  170.2   66.0
# ...    ...   ...   ...   ...   ...    ...    ...    ...    ...    ...    ...
# 3192  2011   0.0  17.9   0.9  62.3   67.9   86.8  196.0  215.8  129.7   74.6
# 3193  2012  37.6   0.0   2.7  24.0   39.3   95.4  221.9  221.2  246.5  140.0
# 3194  2013   2.0  29.6   0.2  48.0   28.2  127.5  162.4  123.1  132.0  411.5
# 3195  2014   0.4   1.2   9.1   6.0  112.9   45.7  151.8  177.8  144.5  195.6
# 3196  2015   2.0   0.6   5.5  32.3   34.1  283.8  116.0  192.0  201.8   59.7
#
#         NOV   DEC  ANNUAL RAIN
# ...

# %%
cor=data4.corr()
cor
# Out:
#                  YEAR       JAN       FEB       MAR       APR       MAY  \
# YEAR         1.000000  0.048132 -0.073781  0.031480 -0.020721  0.049330
# JAN          0.048132  1.000000 -0.062433 -0.019689 -0.065377 -0.025647
# FEB         -0.073781 -0.062433  1.000000  0.173153  0.051741  0.252374
# MAR          0.031480 -0.019689  0.173153  1.000000  0.061019  0.222856
# APR         -0.020721 -0.065377  0.051741  0.061019  1.000000 -0.066308
# MAY          0.049330 -0.025647  0.252374  0.222856 -0.066308  1.000000
# JUN          0.009624 -0.148502 -0.002180 -0.041628 -0.122411 -0.049903
# JUL          0.139075  0.016738 -0.123334 -0.031694 -0.125468 -0.092140
# AUG          0.168372  0.004698  0.007815  0.078904 -0.024127  0.106612
# SEP          0.019305 -0.006220 -0.104363 -0.088769 -0.063572 -0.127919
# OCT          0.004070 -0.076399  0.001682 -0.135138 -0.098969  0.132451
# NOV         -0.037462  0.124096  0.094418 -0.124286 -0.168154  0.096951
# ...

# %%
import seaborn as hh
hh.heatmap(cor,vmax=1,vmin=-1,annot=True,linewidth=5,cmap='bwr')
# Out:
# <Axes: >

# %%
data5=data3.drop(['JAN','FEB','MAR','APR','MAY'],axis=1)

# %%
data5
# Out:
#                  SUBDIVISION  YEAR    JUN    JUL    AUG    SEP    OCT    NOV  \
# 3082  COASTAL ANDHRA PRADESH  1901   77.7  113.0  133.7  125.3  173.4  164.8
# 3083  COASTAL ANDHRA PRADESH  1902   72.6  144.5  236.1  204.5  262.0   50.4
# 3084  COASTAL ANDHRA PRADESH  1903  154.0  248.6  258.0  216.5  159.1  173.9
# 3085  COASTAL ANDHRA PRADESH  1904  107.8  120.2  117.7  116.8  240.9    0.0
# 3086  COASTAL ANDHRA PRADESH  1905   84.4   64.6  210.8  170.2   66.0    7.4
# ...                      ...   ...    ...    ...    ...    ...    ...    ...
# 3192  COASTAL ANDHRA PRADESH  2011   86.8  196.0  215.8  129.7   74.6    4.9
# 3193  COASTAL ANDHRA PRADESH  2012   95.4  221.9  221.2  246.5  140.0  289.7
# 3194  COASTAL ANDHRA PRADESH  2013  127.5  162.4  123.1  132.0  411.5   53.1
# 3195  COASTAL ANDHRA PRADESH  2014   45.7  151.8  177.8  144.5  195.6   23.7
# 3196  COASTAL ANDHRA PRADESH  2015  283.8  116.0  192.0  201.8   59.7   81.2
#
#        DEC  ANNUAL RAIN
# ...

# %%
data5['SWM']=data5.apply(lambda row:row.JUN + row.JUL + row.AUG + row.SEP,axis=1)

# %%
data5
# Out:
#                  SUBDIVISION  YEAR    JUN    JUL    AUG    SEP    OCT    NOV  \
# 3082  COASTAL ANDHRA PRADESH  1901   77.7  113.0  133.7  125.3  173.4  164.8
# 3083  COASTAL ANDHRA PRADESH  1902   72.6  144.5  236.1  204.5  262.0   50.4
# 3084  COASTAL ANDHRA PRADESH  1903  154.0  248.6  258.0  216.5  159.1  173.9
# 3085  COASTAL ANDHRA PRADESH  1904  107.8  120.2  117.7  116.8  240.9    0.0
# 3086  COASTAL ANDHRA PRADESH  1905   84.4   64.6  210.8  170.2   66.0    7.4
# ...                      ...   ...    ...    ...    ...    ...    ...    ...
# 3192  COASTAL ANDHRA PRADESH  2011   86.8  196.0  215.8  129.7   74.6    4.9
# 3193  COASTAL ANDHRA PRADESH  2012   95.4  221.9  221.2  246.5  140.0  289.7
# 3194  COASTAL ANDHRA PRADESH  2013  127.5  162.4  123.1  132.0  411.5   53.1
# 3195  COASTAL ANDHRA PRADESH  2014   45.7  151.8  177.8  144.5  195.6   23.7
# 3196  COASTAL ANDHRA PRADESH  2015  283.8  116.0  192.0  201.8   59.7   81.2
#
#        DEC  ANNUAL RAIN    SWM
# ...

# %%
data5['NEM']=data5.apply(lambda row:row.OCT + row.NOV + row.DEC,axis=1)

# %%
data5
# Out:
#                  SUBDIVISION  YEAR    JUN    JUL    AUG    SEP    OCT    NOV  \
# 3082  COASTAL ANDHRA PRADESH  1901   77.7  113.0  133.7  125.3  173.4  164.8
# 3083  COASTAL ANDHRA PRADESH  1902   72.6  144.5  236.1  204.5  262.0   50.4
# 3084  COASTAL ANDHRA PRADESH  1903  154.0  248.6  258.0  216.5  159.1  173.9
# 3085  COASTAL ANDHRA PRADESH  1904  107.8  120.2  117.7  116.8  240.9    0.0
# 3086  COASTAL ANDHRA PRADESH  1905   84.4   64.6  210.8  170.2   66.0    7.4
# ...                      ...   ...    ...    ...    ...    ...    ...    ...
# 3192  COASTAL ANDHRA PRADESH  2011   86.8  196.0  215.8  129.7   74.6    4.9
# 3193  COASTAL ANDHRA PRADESH  2012   95.4  221.9  221.2  246.5  140.0  289.7
# 3194  COASTAL ANDHRA PRADESH  2013  127.5  162.4  123.1  132.0  411.5   53.1
# 3195  COASTAL ANDHRA PRADESH  2014   45.7  151.8  177.8  144.5  195.6   23.7
# 3196  COASTAL ANDHRA PRADESH  2015  283.8  116.0  192.0  201.8   59.7   81.2
#
#        DEC  ANNUAL RAIN    SWM    NEM
# ...

# %%
data6=data5.drop(['SUBDIVISION'],axis=1)

# %%
data6
# Out:
#       YEAR    JUN    JUL    AUG    SEP    OCT    NOV   DEC  ANNUAL RAIN  \
# 3082  1901   77.7  113.0  133.7  125.3  173.4  164.8   1.5        993.7
# 3083  1902   72.6  144.5  236.1  204.5  262.0   50.4  27.1       1063.5
# 3084  1903  154.0  248.6  258.0  216.5  159.1  173.9  12.1       1316.1
# 3085  1904  107.8  120.2  117.7  116.8  240.9    0.0  10.7        860.1
# 3086  1905   84.4   64.6  210.8  170.2   66.0    7.4   0.0        795.0
# ...    ...    ...    ...    ...    ...    ...    ...   ...          ...
# 3192  2011   86.8  196.0  215.8  129.7   74.6    4.9   5.0        861.8
# 3193  2012   95.4  221.9  221.2  246.5  140.0  289.7   0.0       1318.3
# 3194  2013  127.5  162.4  123.1  132.0  411.5   53.1   2.8       1120.4
# 3195  2014   45.7  151.8  177.8  144.5  195.6   23.7   6.4        875.1
# 3196  2015  283.8  116.0  192.0  201.8   59.7   81.2   2.0       1011.0
#
#         SWM    NEM
# 3082  449.7  339.7
# 3083  657.7  339.5
# 3084  877.1  345.1
# 3085  462.5  251.6
# ...

# %%
data7=data6.drop(['JUN','JUL','AUG','SEP','OCT','NOV','DEC'],axis=1)

# %%
cor=data7.corr()
cor
# Out:
#                  YEAR  ANNUAL RAIN       SWM       NEM
# YEAR         1.000000     0.102054  0.146870 -0.011896
# ANNUAL RAIN  0.102054     1.000000  0.596706  0.677796
# SWM          0.146870     0.596706  1.000000 -0.007822
# NEM         -0.011896     0.677796 -0.007822  1.000000

# %%
import seaborn as hh
hh.heatmap(cor,vmax=1,vmin=-1,annot=True,linewidth=5,cmap='bwr')
# Out:
# <Axes: >
